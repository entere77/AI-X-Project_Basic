# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
import pandas as pd


# 학습/평가 데이터 로딩
df_total = pd.read_csv("total.csv")

# %%
# # 아래에 실습코드를 작성하고 결과를 확인합니다.

# # df_total['1m'] = df_total['총생활인구수'].shift(24*30)
# df_total['2m'] = df_total['총생활인구수'].shift(24*63)
# df_total['4m'] = df_total['총생활인구수'].shift(24*122)
# df_total['6m'] = df_total['총생활인구수'].shift(24*183)
# df_total['8m'] = df_total['총생활인구수'].shift(24*244)
# df_total['10m'] = df_total['총생활인구수'].shift(24*305)
# df_total['12m'] = df_total['총생활인구수'].shift(24*366)

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df_total['기준일ID'] = pd.to_datetime(df_total['기준일ID'], format='%Y%m%d')

df_total['year'] = df_total['기준일ID'].dt.year
df_total['month'] = df_total['기준일ID'].dt.month
df_total['day'] = df_total['기준일ID'].dt.day

# %%
df_total = df_total.dropna()

# %%
df_total
# Out:
#            기준일ID  시간대구분      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0     2017-01-01      0  43922.2281       953.7652         627.7225
# 1     2017-01-01      1  43763.4929       962.2909         633.3292
# 2     2017-01-01      2  43561.5708       932.2939         613.6027
# 3     2017-01-01      3  43928.9929       926.3617         609.7009
# 4     2017-01-01      4  44150.2973       922.8893         607.4184
# ...          ...    ...         ...            ...              ...
# 43507 2021-12-31     19  33304.5400       569.3452         374.9229
# 43508 2021-12-31     20  33368.7201       599.9827         395.0698
# 43509 2021-12-31     21  34083.1721       630.5049         415.1424
# 43510 2021-12-31     22  34380.0806       618.6265         407.3311
# 43511 2021-12-31     23  37074.2785       734.2128         483.3418
#
#        남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 0             927.6134        2025.0630        2278.7336        1744.8161
# ...

# %%
plt.figure(figsize=(40,10))
plt.plot(df_total[(df_total['year']==2021) & (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수'])

# %%
df_total['총생활인구수']
# Out:
# 0        43922.2281
# 1        43763.4929
# 2        43561.5708
# 3        43928.9929
# 4        44150.2973
#             ...
# 43507    33304.5400
# 43508    33368.7201
# 43509    34083.1721
# 43510    34380.0806
# 43511    37074.2785
# Name: 총생활인구수, Length: 43512, dtype: float64

# %%
df_total[(df_total['year']==2021)]['총생활인구수']
# Out:
# 34752    38538.5993
# 34753    38457.1528
# 34754    38185.1451
# 34755    38074.2836
# 34756    38229.0027
#             ...
# 43507    33304.5400
# 43508    33368.7201
# 43509    34083.1721
# 43510    34380.0806
# 43511    37074.2785
# Name: 총생활인구수, Length: 8760, dtype: float64

# %%
df_total[(df_total['year']==2021) & (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수']
# Out:
# 34752    38538.5993
# 34753    38457.1528
# 34754    38185.1451
# 34755    38074.2836
# 34756    38229.0027
#             ...
# 36163    36466.6586
# 36164    36795.4254
# 36165    37333.9824
# 36166    37630.8536
# 36167    40114.2226
# Name: 총생활인구수, Length: 1416, dtype: float64

# %%
plt.figure(figsize=(20,5))
plt.plot(df_total[(df_total['year']==2017)& (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_total[(df_total['year']==2018)& (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_total[(df_total['year']==2019)& (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_total[(df_total['year']==2020)& (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df_total[(df_total['year']==2021)& (df_total['month']>=1) & (df_total['month']<=2)]['총생활인구수'])

# %%
plt.figure(figsize=(40,10))
plt.plot(y_pred_LR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 2
#       1 plt.figure(figsize=(40,10))
# ----> 2 plt.plot(y_pred_LR)
#
# NameError: name 'y_pred_LR' is not defined

# %%
# 아래에 실습코드를 작성하세요.

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
from math import sqrt

LR_reg = LinearRegression()
LR_reg.fit(train_x, train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 9
#       6 from math import sqrt
#       8 LR_reg = LinearRegression()
# ----> 9 LR_reg.fit(train_x, train_y)
#
# NameError: name 'train_x' is not defined

# %%
# Test 데이터로 성능을 평가해보세요.

y_pred_LR = LR_reg.predict(test_x)

print('LinearRegression')
print("Mean Squared Error : {0:.5f}".format(mse(test_y,y_pred_LR)))
print("Root Mean Squared Error : {0:.5f}".format(sqrt(mse(test_y,y_pred_LR))))
print("r2 : ", r2(test_y,y_pred_LR))

# %%
sub = pd.read_csv("sample_submission.csv")
sub
# Out:
#         id  count
# 0        0  12345
# 1        1  12345
# 2        2  12345
# 3        3  12345
# 4        4  12345
# ...    ...    ...
# 1411  1411  12345
# 1412  1412  12345
# 1413  1413  12345
# 1414  1414  12345
# 1415  1415  12345
#
# [1416 rows x 2 columns]

# %%
sub['count'] = y_pred_LR

# %%
sub.head(20)
# Out:
#     id         count
# 0    0  40213.878719
# 1    1  40092.459619
# 2    2  40017.461786
# 3    3  39939.067902
# 4    4  39975.404779
# 5    5  39837.887096
# 6    6  39890.574925
# 7    7  39948.258657
# 8    8  39150.841964
# 9    9  38613.060121
# 10  10  38085.405652
# 11  11  37778.207749
# 12  12  37479.518984
# 13  13  36949.942015
# 14  14  36557.072853
# 15  15  36199.771090
# 16  16  36080.184939
# 17  17  36207.022107
# 18  18  36513.859002
# 19  19  36591.914604
